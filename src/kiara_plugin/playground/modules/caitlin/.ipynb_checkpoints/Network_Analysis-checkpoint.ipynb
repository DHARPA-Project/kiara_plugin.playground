# %% [markdown]
# <h2><i>kiara</i>: Network Analysis</h2>
#
# Welcome back! Now that we're comfortable with what <i>kiara</i> looks like and what it can do to help track your data and your research process, let's try out some of the digital analysis tools, starting with <b>Network Analysis</b>.
#
# <h2>Why Network Analysis?</h2>
#
# Network Analysis offers a computational and quantitative means to examine and explore relational objects, with proxies to measure structural roles and concepts such as power and influence. Doing so digitally - and at scale -also allows us to consider these kinds of questions with large amounts of material or documents that could not be heretofore managed with qualitative approaches.
#
# <h3>Getting Started</h3>
#
# Let's start by double checking that we have all the required plugins and setting up an API for us to use <i>kiara</i>. We'll do this all in one go this time, but if you're unsure, feel free to head back to the <a href="http://dharpa.org/kiara.documentation/latest/workshop/workshop/">installation notebook</a> to look over this section again.

# %%
import csv
import networkx as nx
import matplotlib.pyplot as plt

try:
    from kiara_plugin.jupyter import ensure_kiara_plugins
except:
    import sys
    print("Installing 'kiara_plugin.jupyter'...")
    # !{sys.executable} -m pip install -q kiara_plugin.jupyter
    from kiara_plugin.jupyter import ensure_kiara_plugins

ensure_kiara_plugins()

from kiara.api import KiaraAPI
kiara = KiaraAPI.instance()

# %% [markdown]
# Great, we're all set up. Let's download some sample data for our network analysis: this is some epistolary data taken from the <i>State Papers of England</i> between 1534-1540.
#
# <span style="color:blue">insert links for references when needed</span>
#
# As before, we can use the <i>kiara</i> function `download.file` to access our material, specifying the <span style="color:green">inputs</span> and runnning the function as our <span style="color:red">outputs</span>.

# %%
inputs = {
        "url": "https://raw.githubusercontent.com/CBurge95/kiara.documentation/develop/examples/data/1534-1540_copy.csv",
        "file_name": "sample"
}

outputs = kiara.run_job('download.file', inputs=inputs)

outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field               value                                                                                                              │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────      │
# │   download_metadata                                                                                                                      │
# │                         dict data     {                                                                                                  │
# │                                         "response_headers": [                                                                            │
# │                                           {                                                                                              │
# │                                             "connection": "keep-alive",                                                                  │
# │                                             "content-length": "37901",                                                                   │
# │                                             "cache-control": "max-age=300",                                                              │
# │                                             "content-security-policy": "default-src 'none'; style-src 'unsafe-inline'; sandbox",         │
# │                                             "content-type": "text/plain; charset=utf-8",                                                 │
# │                                             "etag": "W/\"8a118ba2938744c4a23280acde2afd16fdf4668a39fe64a77325aaff3f50475f\"",            │
# │                                             "strict-transport-security": "max-age=31536000",                                             │
# │                                             "x-content-type-options": "nosniff",                                                         │
# │                                             "x-frame-options": "deny",                                                                   │
# │                                             "x-xss-protection": "1; mode=block",                                                         │
# │                                             "x-github-request-id": "EC88:5EEF:34BA1A:53949B:63F87DB9",                                   │
# │                                             "content-encoding": "gzip",                                                                  │
# │                                             "accept-ranges": "bytes",                                                                    │
# │                                             "date": "Fri, 24 Feb 2023 09:05:42 GMT",                                                     │
# │                                             "via": "1.1 varnish",                                                                        │
# │                                             "x-served-by": "cache-hhn-etou8220031-HHN",                                                  │
# │                                             "x-cache": "HIT",                                                                            │
# │                                             "x-cache-hits": "1",                                                                         │
# │                                             "x-timer": "S1677229543.604770,VS0,VE1",                                                     │
# │                                             "vary": "Authorization,Accept-Encoding,Origin",                                              │
# │                                             "access-control-allow-origin": "*",                                                          │
# │                                             "x-fastly-request-id": "899a7e6f160dfdb1d02c291a753a566c6e3f34a5",                           │
# │                                             "expires": "Fri, 24 Feb 2023 09:10:42 GMT",                                                  │
# │                                             "source-age": "45"                                                                           │
# │                                           }                                                                                              │
# │                                         ],                                                                                               │
# │                                         "request_time": "2023-02-24T09:05:42.618883+00:00"                                               │
# │                                       }                                                                                                  │
# │                         dict schema   {                                                                                                  │
# │                                         "title": "dict",                                                                                 │
# │                                         "type": "object"                                                                                 │
# │                                       }                                                                                                  │
# │                                                                                                                                          │
# │   file                Source,Target                                                                                                      │
# │                       10004,32545                                                                                                        │
# │                       1006,32545                                                                                                         │
# │                       10132,32545                                                                                                        │
# │                       1041,11844                                                                                                         │
# │                       10503,8608                                                                                                         │
# │                       1085,32545                                                                                                         │
# │                       11196,32545                                                                                                        │
# │                       11383,35584                                                                                                        │
# │                       11552,32545                                                                                                        │
# │                       11556,1683                                                                                                         │
# │                       11581,32545                                                                                                        │
# │                       11607,32545                                                                                                        │
# │                       11607,32851                                                                                                        │
# │                       11844,13296                                                                                                        │
# │                       11844,13296                                                                                                        │
# │                       11844,3229                                                                                                         │
# │                       11844,3229                                                                                                         │
# │                       11844,32539                                                                                                        │
# │                       11844,9194                                                                                                         │
# │                       12014,32545                                                                                                        │
# │                       12207,32545                                                                                                        │
# │                       12220,32545                                                                                                        │
# │                       1228,12118                                                                                                         │
# │                       12968,32545                                                                                                        │
# │                       13161,32545                                                                                                        │
# │                       13196,11844                                                                                                        │
# │                       13296,11844                                                                                                        │
# │                       13296,1394                                                                                                         │
# │                       13296,16533                                                                                                        │
# │                       13296,24082                                                                                                        │
# │                       13296,27933                                                                                                        │
# │                       13296,3731                                                                                                         │
# │                       13296,4232                                                                                                         │
# │                       13939,32545                                                                                                        │
# │                       ...                                                                                                                │
# │                                                                                                                                          │
# │                       ...                                                                                                                │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# <h2>Creating a Network</h2>
#
# Time to make our network from this data. Let's start by searching for the <i>kiara</i> modules that are included in the `kiara_plugin.network_analysis` package.

# %%
infos = metadata = kiara.retrieve_operations_info()
operations = {}
for op_id, info in infos.item_infos.items():
    if info.context.labels.get("package", None) == "kiara_plugin.network_analysis":
        operations[op_id] = info

print(operations.keys())
# Out:
# dict_keys(['create.network_data.from.tables', 'export.network_data.as.csv_files', 'export.network_data.as.graphml_file', 'export.network_data.as.sql_dump', 'export.network_data.as.sqlite_db', 'network_data.check_clusters'])

# %% [markdown]
# There's lots of options for analysis, but we want to make our network first. Let's have a look what we need with the function `create.network_data.from.tables` using `kiara.retrieve_operation_info` once more.
#
# <span style="color:blue">this will make more sense/have more options when analysis modules are incorporated into the network plugin</span>

# %%
kiara.retrieve_operation_info('create.network_data.from.tables')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         network_analysis
#                      Labels       package: kiara_plugin.network_analysis
#                      References   source_repo: ]8;id=406807;https://github.com/DHARPA-Project/kiara_plugin.network_analysis\https://github.com/DHARPA-Project/kiara_plugin.network_analysis]8;;\
#                                   documentation: ]8;id=371315;https://DHARPA-Project.github.io/kiara_plugin.network_analysis/\https://DHARPA-Project.github.io/kiara_plugin.network_analysis/]8;;\
#
#  Operation details
#                      Documentation   Create a graph object from one or two tables.
#
#                                      This module needs at least one table as input, providing the edges of the resulting network data
#                                      set.
#                                      If no further table is created, basic node information will be automatically created by using unique
#                                      values from
#                                      the edges source and target columns.
#
#                      Inputs
#                                        field name           type     description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        edges                table    A table that contains the edges        yes        -- no default --
#                                                                      data.
#                                        source_column_name   string   The name of the source column name     no         source
#                                                                      in the edges table.
#                                        target_column_name   string   The name of the target column name     no         target
#                                                                      in the edges table.
#                                        edges_column_map     dict     An optional map of original column     no         -- no default --
#                                                                      name to desired.
#                                        nodes                table    A table that contains the nodes        no         -- no default --
#                                                                      data.
#                                        id_column_name       string   The name (before any potential         no         id
#                                                                      column mapping) of the node-table
#                                                                      column that contains the node
#                                                                      identifier (used in the edges
#                                                                      table).
#                                        label_column_name    string   The name of a column that contains     no         -- no default --
#                                                                      the node label (before any potential
#                                                                      column name mapping). If not
#                                                                      specified, the value of the id value
#                                                                      will be used as label.
#                                        nodes_column_map     dict     An optional map of original column     no         -- no default --
#                                                                      name to desired.
#
#
#                      Outputs
#                                        field name     type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network/graph data.

# %% [markdown]
# Like other network analysis tools, <i>kiara</i> first needs the data as an edge table. This means we first have to transform the data we downloaded earlier into a table before we can create the network data. Let's start by using the `create.table.from.file` function that we used in the first notebook and storing this as our <b>edges</b>, then use this to create our network data using the `create.network_data.from.tables` that we just read about. In this, we are defining two different sets of <span style="color:green">inputs</span>, overriding the first variable once we have used it to create our table.
#
# We're going to be using the network data quite a lot in the rest of the notebook, so lets store the output for this function as <b>network_data</b>. We can import a separate table with the nodes in, but this is optional, and for the moment let's stick with just the edge table.

# %%
inputs = {
    "file": outputs['file']
}

outputs = kiara.run_job('create.table.from.file', inputs=inputs)

edges = outputs['table']

inputs = {
    'edges' : edges,
    'source_column_name' : 'Source',
    'target_column_name' : 'Target'
}

network = kiara.run_job('create.network_data.from.tables', inputs=inputs)
network_data = network['network_data']
network
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ────────────────────────────────────                                                                                                    │
# │   network_data                                                                                                                           │
# │                  Table: edges                                                                                                            │
# │                                                                                                                                          │
# │                    source   target                                                                                                       │
# │                   ─────────────────                                                                                                      │
# │                    10004    32545                                                                                                        │
# │                    1006     32545                                                                                                        │
# │                    10132    32545                                                                                                        │
# │                    1041     11844                                                                                                        │
# │                    10503    8608                                                                                                         │
# │                    1085     32545                                                                                                        │
# │                    11196    32545                                                                                                        │
# │                    11383    35584                                                                                                        │
# │                    11552    32545                                                                                                        │
# │                    11556    1683                                                                                                         │
# │                    11581    32545                                                                                                        │
# │                    11607    32545                                                                                                        │
# │                    11607    32851                                                                                                        │
# │                    11844    13296                                                                                                        │
# │                    11844    13296                                                                                                        │
# │                    11844    3229                                                                                                         │
# │                    ...      ...                                                                                                          │
# │                    ...      ...                                                                                                          │
# │                    11844    4721                                                                                                         │
# │                    29151    32545                                                                                                        │
# │                    29345    32545                                                                                                        │
# │                    23020    11844                                                                                                        │
# │                    23020    32545                                                                                                        │
# │                    28688    15766                                                                                                        │
# │                    28688    15766                                                                                                        │
# │                    28688    29214                                                                                                        │
# │                    4084     1057                                                                                                         │
# │                    4084     9194                                                                                                         │
# │                    14692    29617                                                                                                        │
# │                    27309    32545                                                                                                        │
# │                    8270     25016                                                                                                        │
# │                    14832    11844                                                                                                        │
# │                    30246    32545                                                                                                        │
# │                    33420    32545                                                                                                        │
# │                                                                                                                                          │
# │                  Table: nodes                                                                                                            │
# │                                                                                                                                          │
# │                    id      label                                                                                                         │
# │                   ───────────────                                                                                                        │
# │                    14342   14342                                                                                                         │
# │                    8201    8201                                                                                                          │
# │                    22538   22538                                                                                                         │
# │                    12300   12300                                                                                                         │
# │                    34834   34834                                                                                                         │
# │                    18      18                                                                                                            │
# │                    24595   24595                                                                                                         │
# │                    20501   20501                                                                                                         │
# │                    10266   10266                                                                                                         │
# │                    28700   28700                                                                                                         │
# │                    4132    4132                                                                                                          │
# │                    28711   28711                                                                                                         │
# │                    8234    8234                                                                                                          │
# │                    8236    8236                                                                                                          │
# │                    14383   14383                                                                                                         │
# │                    47      47                                                                                                            │
# │                    ...     ...                                                                                                           │
# │                    ...     ...                                                                                                           │
# │                    11727   11727                                                                                                         │
# │                    3536    3536                                                                                                          │
# │                    16849   16849                                                                                                         │
# │                    19924   19924                                                                                                         │
# │                    36308   36308                                                                                                         │
# │                    33751   33751                                                                                                         │
# │                    18396   18396                                                                                                         │
# │                    35293   35293                                                                                                         │
# │                    1505    1505                                                                                                          │
# │                    23534   23534                                                                                                         │
# │                    5616    5616                                                                                                          │
# │                    24050   24050                                                                                                         │
# │                    4087    4087                                                                                                          │
# │                    14328   14328                                                                                                         │
# │                    36345   36345                                                                                                         │
# │                    32762   32762                                                                                                         │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Now we've successfully transformed our downloaded into a table and created some network data from it - presented as a list of <b>edges</b> and a list of <b>nodes</b> - we can find out some more information about the network we have created. Let's have a look at the options for `get.network_info`.

# %%
kiara.retrieve_operation_info('get.network_info')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=171537;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=745608;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Return basic information for the newtork graph created, including number of nodes and edges.
#
#                                      Needs to specify if graph is directed or undirected, but will default to undirected.
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network graph being queried.       yes        -- no default --
#                                        graph_type     string         The graph type: directed or            no         undirected
#                                                                      undirected
#
#
#                      Outputs
#                                        field name       type     description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result   string   Information about the network graph.

# %% [markdown]
# So here we just need to add the network data that we want to find out about. We can also use this as an opportunity to make our network data into a <b>directed network</b>, or leave it as an <b>undirected network</b> as the default.
#
# Let's leave it as is for the moment, and see what information we can gather.
#
# This time, we're going to define the inputs within the `kiara.run_job` function, and print this immediately, rather than storing it in a variable, much like we do when we run `kiara.retrieve_operation_info`.

# %%
#kiara.run_job('get.network_info', inputs={'network_data':network_data})

# %% [markdown]
# <h2>Network Analysis: Statistical Measures</h2>

# %%
kiara.retrieve_operation_info('create.degree_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=473969;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=470550;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for degree centrality.
#
#                                      In an undirected graph, degree centrality measures the number of independent connections each node
#                                      has.
#
#                                      Uses networkx degree.
#                                      https://networkx.org/documentation/stable/reference/generated/networkx.classes.function.degree.html
#
#                      Inputs
#                                        field name           type           description                      Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data         network_data   The network graph being          yes        -- no default --
#                                                                            queried.
#                                        weighted_degree      boolean        Boolean to indicate whether to   no         True
#                                                                            calculate weighted degree or
#                                                                            not. Conditions for
#                                                                            calculation can be set in
#                                                                            'weight_column_name'.
#                                        weight_column_name   string         The name of the column in the    no
#                                                                            edge table containing data for
#                                                                            the 'weight' or 'strength' of
#                                                                            an edge. If there is a column
#                                                                            already named 'weight', this
#                                                                            will be automatically
#                                                                            selected. If otherwise left
#                                                                            empty, weighted degree is
#                                                                            calculated by aggregrating
#                                                                            parallel edges where edge
#                                                                            weight is assigned a weight of
#                                                                            1.
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for degree
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with degree ranking assigned as a node
#                                                                            attribute.

# %%
output = kiara.run_job('create.degree_rank_list', inputs={'network_data':network_data})
output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ───────────────────────────────────────────────────────────────────────────────                                                         │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source   target                                                                                                 │
# │                         ─────────────────                                                                                                │
# │                          14342    32539                                                                                                  │
# │                          14342    32545                                                                                                  │
# │                          14342    14368                                                                                                  │
# │                          14342    4945                                                                                                   │
# │                          14342    11375                                                                                                  │
# │                          8201     15754                                                                                                  │
# │                          22538    4421                                                                                                   │
# │                          12300    11844                                                                                                  │
# │                          12300    32545                                                                                                  │
# │                          34834    32545                                                                                                  │
# │                          18       11844                                                                                                  │
# │                          24595    33158                                                                                                  │
# │                          20501    32545                                                                                                  │
# │                          10266    12118                                                                                                  │
# │                          10266    1683                                                                                                   │
# │                          28700    32545                                                                                                  │
# │                          ...      ...                                                                                                    │
# │                          ...      ...                                                                                                    │
# │                          2108     32703                                                                                                  │
# │                          9876     7460                                                                                                   │
# │                          22166    36167                                                                                                  │
# │                          24220    33765                                                                                                  │
# │                          7460     30709                                                                                                  │
# │                          19426    4084                                                                                                   │
# │                          4084     36656                                                                                                  │
# │                          4084     34411                                                                                                  │
# │                          27141    14328                                                                                                  │
# │                          28688    36753                                                                                                  │
# │                          5139     22082                                                                                                  │
# │                          15915    6531                                                                                                   │
# │                          15528    21163                                                                                                  │
# │                          32462    23534                                                                                                  │
# │                          13018    21258                                                                                                  │
# │                          17762    4087                                                                                                   │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Weighted Degree Score   Degree Score   label   id                                                               │
# │                         ──────────────────────────────────────────────────────                                                           │
# │                          17                      5              14342   14342                                                            │
# │                          1                       1              8201    8201                                                             │
# │                          1                       1              22538   22538                                                            │
# │                          5                       2              12300   12300                                                            │
# │                          1                       1              34834   34834                                                            │
# │                          1                       1              18      18                                                               │
# │                          1                       1              24595   24595                                                            │
# │                          1                       1              20501   20501                                                            │
# │                          14                      2              10266   10266                                                            │
# │                          2                       2              28700   28700                                                            │
# │                          1                       1              4132    4132                                                             │
# │                          51                      8              28711   28711                                                            │
# │                          1                       1              8234    8234                                                             │
# │                          1                       1              8236    8236                                                             │
# │                          15                      6              14383   14383                                                            │
# │                          3                       3              47      47                                                               │
# │                          ...                     ...            ...     ...                                                              │
# │                          ...                     ...            ...     ...                                                              │
# │                          2                       2              11727   11727                                                            │
# │                          1                       1              3536    3536                                                             │
# │                          1                       1              16849   16849                                                            │
# │                          1                       1              19924   19924                                                            │
# │                          1                       1              36308   36308                                                            │
# │                          1                       1              33751   33751                                                            │
# │                          1                       1              18396   18396                                                            │
# │                          1                       1              35293   35293                                                            │
# │                          3                       2              1505    1505                                                             │
# │                          1                       1              23534   23534                                                            │
# │                          1                       1              5616    5616                                                             │
# │                          1                       1              24050   24050                                                            │
# │                          1                       1              4087    4087                                                             │
# │                          1                       1              14328   14328                                                            │
# │                          1                       1              36345   36345                                                            │
# │                          1                       1              32762   32762                                                            │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Rank   Node    Degree   Weighted Degree                                                                         │
# │                         ─────────────────────────────────────────                                                                        │
# │                          1      32545   1656     6422                                                                                    │
# │                          2      11844   344      1152                                                                                    │
# │                          3      1683    326      1471                                                                                    │
# │                          4      12118   169      755                                                                                     │
# │                          5      33564   151      320                                                                                     │
# │                          6      32851   75       362                                                                                     │
# │                          7      13296   57       216                                                                                     │
# │                          8      3641    49       168                                                                                     │
# │                          9      32539   47       208                                                                                     │
# │                          9      12113   47       348                                                                                     │
# │                          11     37299   32       156                                                                                     │
# │                          11     3256    32       81                                                                                      │
# │                          11     24566   32       107                                                                                     │
# │                          14     3982    31       103                                                                                     │
# │                          15     24128   29       86                                                                                      │
# │                          16     9194    24       166                                                                                     │
# │                          ...    ...     ...      ...                                                                                     │
# │                          ...    ...     ...      ...                                                                                     │
# │                          841    1481    1        1                                                                                       │
# │                          841    17867   1        1                                                                                       │
# │                          841    3536    1        1                                                                                       │
# │                          841    16849   1        1                                                                                       │
# │                          841    19924   1        1                                                                                       │
# │                          841    36308   1        1                                                                                       │
# │                          841    33751   1        1                                                                                       │
# │                          841    18396   1        1                                                                                       │
# │                          841    35293   1        1                                                                                       │
# │                          841    23534   1        1                                                                                       │
# │                          841    5616    1        1                                                                                       │
# │                          841    24050   1        1                                                                                       │
# │                          841    4087    1        1                                                                                       │
# │                          841    14328   1        1                                                                                       │
# │                          841    36345   1        1                                                                                       │
# │                          841    32762   1        1                                                                                       │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
"""inputs = {
    "table": output['network_result'],
    "query": "SELECT * from data where Score BETWEEN 20 AND 75"
}

query = kiara.run_job('query.table', inputs=inputs)

query"""
# Out:
# 'inputs = {\n    "table": output[\'network_result\'],\n    "query": "SELECT * from data where Score BETWEEN 20 AND 75"\n}\n\nquery = kiara.run_job(\'query.table\', inputs=inputs)\n\nquery'

# %%
kiara.retrieve_operation_info('create.betweenness_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=426984;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=724640;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for betweenness centrality.
#
#                                      In an undirected graph, betweenness centrality measures the percentage of all shortest paths that a
#                                      node appears on, therefore measuring the likeliness that a node may act as a connector or
#                                      'intermediary'.
#
#                                      Uses networkx.betweenness_centrality()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centra…
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network graph being queried.       yes        -- no default --
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for betweenness
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with betweenness ranking assigned as a
#                                                                            node attribute.

# %%
centrality_network = output['centrality_network']

output = kiara.run_job('create.betweenness_rank_list', inputs={'network_data':centrality_network})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ────────────────────────────────────────────────────────────────────────────────────────────────────────                                │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source   target                                                                                                 │
# │                         ─────────────────                                                                                                │
# │                          14342    32539                                                                                                  │
# │                          14342    32545                                                                                                  │
# │                          14342    14368                                                                                                  │
# │                          14342    4945                                                                                                   │
# │                          14342    11375                                                                                                  │
# │                          8201     15754                                                                                                  │
# │                          22538    4421                                                                                                   │
# │                          12300    11844                                                                                                  │
# │                          12300    32545                                                                                                  │
# │                          34834    32545                                                                                                  │
# │                          18       11844                                                                                                  │
# │                          24595    33158                                                                                                  │
# │                          20501    32545                                                                                                  │
# │                          10266    12118                                                                                                  │
# │                          10266    1683                                                                                                   │
# │                          28700    32545                                                                                                  │
# │                          ...      ...                                                                                                    │
# │                          ...      ...                                                                                                    │
# │                          2108     32703                                                                                                  │
# │                          9876     7460                                                                                                   │
# │                          22166    36167                                                                                                  │
# │                          24220    33765                                                                                                  │
# │                          7460     30709                                                                                                  │
# │                          19426    4084                                                                                                   │
# │                          4084     36656                                                                                                  │
# │                          4084     34411                                                                                                  │
# │                          27141    14328                                                                                                  │
# │                          28688    36753                                                                                                  │
# │                          5139     22082                                                                                                  │
# │                          15915    6531                                                                                                   │
# │                          15528    21163                                                                                                  │
# │                          32462    23534                                                                                                  │
# │                          13018    21258                                                                                                  │
# │                          17762    4087                                                                                                   │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Weighted Degree Score   Degree Score   Betweenness Score        label   id                                      │
# │                         ───────────────────────────────────────────────────────────────────────────────                                  │
# │                          17                      5              0.0031188508321272615    14342   14342                                   │
# │                          1                       1              0.0                      8201    8201                                    │
# │                          1                       1              0.0                      22538   22538                                   │
# │                          5                       2              0.0                      12300   12300                                   │
# │                          1                       1              0.0                      34834   34834                                   │
# │                          1                       1              0.0                      18      18                                      │
# │                          1                       1              0.0                      24595   24595                                   │
# │                          1                       1              0.0                      20501   20501                                   │
# │                          14                      2              0.0                      10266   10266                                   │
# │                          2                       2              0.0                      28700   28700                                   │
# │                          1                       1              0.0                      4132    4132                                    │
# │                          51                      8              0.0006372242315166842    28711   28711                                   │
# │                          1                       1              0.0                      8234    8234                                    │
# │                          1                       1              0.0                      8236    8236                                    │
# │                          15                      6              0.00013032538158398984   14383   14383                                   │
# │                          3                       3              0.0005898902177397989    47      47                                      │
# │                          ...                     ...            ...                      ...     ...                                     │
# │                          ...                     ...            ...                      ...     ...                                     │
# │                          2                       2              0.0                      11727   11727                                   │
# │                          1                       1              0.0                      3536    3536                                    │
# │                          1                       1              0.0                      16849   16849                                   │
# │                          1                       1              0.0                      19924   19924                                   │
# │                          1                       1              0.0                      36308   36308                                   │
# │                          1                       1              0.0                      33751   33751                                   │
# │                          1                       1              0.0                      18396   18396                                   │
# │                          1                       1              0.0                      35293   35293                                   │
# │                          3                       2              0.0                      1505    1505                                    │
# │                          1                       1              0.0                      23534   23534                                   │
# │                          1                       1              0.0                      5616    5616                                    │
# │                          1                       1              0.0                      24050   24050                                   │
# │                          1                       1              0.0                      4087    4087                                    │
# │                          1                       1              0.0                      14328   14328                                   │
# │                          1                       1              0.0                      36345   36345                                   │
# │                          1                       1              0.0                      32762   32762                                   │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Rank   Node    Score                                                                                            │
# │                         ─────────────────────────────────────                                                                            │
# │                          1      32545   0.6992703318930911                                                                               │
# │                          2      1683    0.11658792348336017                                                                              │
# │                          3      11844   0.11255016242543292                                                                              │
# │                          4      12118   0.06367681709086949                                                                              │
# │                          5      33564   0.039784581315441374                                                                             │
# │                          6      13296   0.02550229176631329                                                                              │
# │                          7      12113   0.020591383996174002                                                                             │
# │                          8      32539   0.01866557598510336                                                                              │
# │                          9      3641    0.017275586462350105                                                                             │
# │                          10     32851   0.013639543317114082                                                                             │
# │                          11     1057    0.010644339958545756                                                                             │
# │                          12     24128   0.010399155089429799                                                                             │
# │                          13     19683   0.008979148774853642                                                                             │
# │                          14     26359   0.007213234700675651                                                                             │
# │                          15     3256    0.006247897989543195                                                                             │
# │                          16     12019   0.006109031857128004                                                                             │
# │                          ...    ...     ...                                                                                              │
# │                          ...    ...     ...                                                                                              │
# │                          549    11727   0.0                                                                                              │
# │                          549    3536    0.0                                                                                              │
# │                          549    16849   0.0                                                                                              │
# │                          549    19924   0.0                                                                                              │
# │                          549    36308   0.0                                                                                              │
# │                          549    33751   0.0                                                                                              │
# │                          549    18396   0.0                                                                                              │
# │                          549    35293   0.0                                                                                              │
# │                          549    1505    0.0                                                                                              │
# │                          549    23534   0.0                                                                                              │
# │                          549    5616    0.0                                                                                              │
# │                          549    24050   0.0                                                                                              │
# │                          549    4087    0.0                                                                                              │
# │                          549    14328   0.0                                                                                              │
# │                          549    36345   0.0                                                                                              │
# │                          549    32762   0.0                                                                                              │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
kiara.retrieve_operation_info('create.eigenvector_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=823001;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=567355;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for betweenness centrality.
#
#                                      In an undirected graph, eigenvector centrality measures the extent to which a node is connected to
#                                      other nodes of importance or influence.
#
#                                      Uses networkx.eigenvector_centrality()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centra…
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network graph being queried.       yes        -- no default --
#                                        iterations     integer        -- n/a --                              no         1000
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for eigenvector
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with eigenvector ranking assigned as a
#                                                                            node attribute.

# %%
centrality_network = output['centrality_network']

output = kiara.run_job('create.eigenvector_rank_list', inputs={'network_data':centrality_network})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────       │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source   target                                                                                                 │
# │                         ─────────────────                                                                                                │
# │                          14342    32539                                                                                                  │
# │                          14342    32545                                                                                                  │
# │                          14342    14368                                                                                                  │
# │                          14342    4945                                                                                                   │
# │                          14342    11375                                                                                                  │
# │                          8201     15754                                                                                                  │
# │                          22538    4421                                                                                                   │
# │                          12300    11844                                                                                                  │
# │                          12300    32545                                                                                                  │
# │                          34834    32545                                                                                                  │
# │                          18       11844                                                                                                  │
# │                          24595    33158                                                                                                  │
# │                          20501    32545                                                                                                  │
# │                          10266    12118                                                                                                  │
# │                          10266    1683                                                                                                   │
# │                          28700    32545                                                                                                  │
# │                          ...      ...                                                                                                    │
# │                          ...      ...                                                                                                    │
# │                          2108     32703                                                                                                  │
# │                          9876     7460                                                                                                   │
# │                          22166    36167                                                                                                  │
# │                          24220    33765                                                                                                  │
# │                          7460     30709                                                                                                  │
# │                          19426    4084                                                                                                   │
# │                          4084     36656                                                                                                  │
# │                          4084     34411                                                                                                  │
# │                          27141    14328                                                                                                  │
# │                          28688    36753                                                                                                  │
# │                          5139     22082                                                                                                  │
# │                          15915    6531                                                                                                   │
# │                          15528    21163                                                                                                  │
# │                          32462    23534                                                                                                  │
# │                          13018    21258                                                                                                  │
# │                          17762    4087                                                                                                   │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Weighted Degree Score   Degree Score   Betweenness Score        label   Eigenvector Score        id             │
# │                         ────────────────────────────────────────────────────────────────────────────────────────────────────────         │
# │                          17                      5              0.0031188508321272615    14342   0.016931568162542127     14342          │
# │                          1                       1              0.0                      8201    5.520694950732246e-157   8201           │
# │                          1                       1              0.0                      22538   5.520694950732246e-157   22538          │
# │                          5                       2              0.0                      12300   0.01931681692052766      12300          │
# │                          1                       1              0.0                      34834   0.016153810562303077     34834          │
# │                          1                       1              0.0                      18      0.0031630063582245857    18             │
# │                          1                       1              0.0                      24595   5.520694950732246e-157   24595          │
# │                          2895   32462   5.520694950732246e-157                                                                           │
# │                          2895   13018   5.520694950732246e-157                                                                           │
# │                          2895   21258   5.520694950732246e-157                                                                           │
# │                          2895   17762   5.520694950732246e-157                                                                           │
# │                          2895   6531    5.520694950732246e-157                                                                           │
# │                          2895   23534   5.520694950732246e-157                                                                           │
# │                          2895   4087    5.520694950732246e-157                                                                           │
# │                          2895   14328   5.520694950732246e-157                                                                           │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
kiara.retrieve_operation_info('create.closeness_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=339225;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=893828;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for closeness centrality.
#
#                                      In an undirected graph, closeness centrality measures the average shortest distance path between a
#                                      node and all reachable nodes in the network.
#
#                                      Uses networkx.closeness_centrality()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centra…
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network graph being queried.       yes        -- no default --
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for closeness
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with closeness ranking assigned as a
#                                                                            node attribute.

# %%
centrality_network = output['centrality_network']

output = kiara.run_job('create.closeness_rank_list', inputs={'network_data':centrality_network})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source   target                                                                                                 │
# │                         ─────────────────                                                                                                │
# │                          14342    32539                                                                                                  │
# │                          14342    32545                                                                                                  │
# │                          14342    14368                                                                                                  │
# │                          14342    4945                                                                                                   │
# │                          14342    11375                                                                                                  │
# │                          8201     15754                                                                                                  │
# │                          22538    4421                                                                                                   │
# │                          12300    11844                                                                                                  │
# │                          12300    32545                                                                                                  │
# │                          34834    32545                                                                                                  │
# │                          18       11844                                                                                                  │
# │                          24595    33158                                                                                                  │
# │                          20501    32545                                                                                                  │
# │                          10266    12118                                                                                                  │
# │                          10266    1683                                                                                                   │
# │                          28700    32545                                                                                                  │
# │                          ...      ...                                                                                                    │
# │                          ...      ...                                                                                                    │
# │                          2108     32703                                                                                                  │
# │                          9876     7460                                                                                                   │
# │                          22166    36167                                                                                                  │
# │                          24220    33765                                                                                                  │
# │                          7460     30709                                                                                                  │
# │                          19426    4084                                                                                                   │
# │                          4084     36656                                                                                                  │
# │                          4084     34411                                                                                                  │
# │                          27141    14328                                                                                                  │
# │                          28688    36753                                                                                                  │
# │                          5139     22082                                                                                                  │
# │                          15915    6531                                                                                                   │
# │                          15528    21163                                                                                                  │
# │                          32462    23534                                                                                                  │
# │                          13018    21258                                                                                                  │
# │                          17762    4087                                                                                                   │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Weighted Degree S   Closeness Score     Degree Score   Betweenness Score   label   Eigenvector Scor   id        │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          17                  0.371983114391572   5              0.003118850832127   14342   0.01693156816254   14342     │
# │                          1                   0.000321027287319   1              0.0                 8201    5.52069495073224   8201      │
# │                          1                   0.000321027287319   1              0.0                 22538   5.52069495073224   22538     │
# │                          5                   0.379116008597755   2              0.0                 12300   0.01931681692052   12300     │
# │                          1                   0.368593865381837   1              0.0                 34834   0.01615381056230   34834     │
# │                          1                   0.303783345151805   1              0.0                 18      0.00316300635822   18        │
# │                          1                   0.000321027287319   1              0.0                 24595   5.52069495073224   24595     │
# │                          1                   0.368593865381837   1              0.0                 20501   0.01615381056230   20501     │
# │                          14                  0.302038667084083   2              0.0                 10266   0.00351102448116   10266     │
# │                          2                   0.368852382611029   2              0.0                 28700   0.01671845728289   28700     │
# │                          2895   21163   0.00032102728731942215                                                                           │
# │                          2895   32462   0.00032102728731942215                                                                           │
# │                          2895   13018   0.00032102728731942215                                                                           │
# │                          2895   21258   0.00032102728731942215                                                                           │
# │                          2895   17762   0.00032102728731942215                                                                           │
# │                          2895   6531    0.00032102728731942215                                                                           │
# │                          2895   23534   0.00032102728731942215                                                                           │
# │                          2895   4087    0.00032102728731942215                                                                           │
# │                          2895   14328   0.00032102728731942215                                                                           │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
kiara.retrieve_operation_info('create.cut_point_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge              caitlin.burge@uni.lu
#                      Mariella De Crouy Chanel   mariella.decrouychanel@uni.lu
#
#  Context
#                      Tags         playground
#                      Labels       package: kiara_plugin.playground
#                      References   source_repo: ]8;id=974292;https://github.com/DHARPA-Project/kiara_plugin.playground\https://github.com/DHARPA-Project/kiara_plugin.playground]8;;\
#                                   documentation: ]8;id=387728;https://DHARPA-Project.github.io/kiara_plugin.playground/\https://DHARPA-Project.github.io/kiara_plugin.playground/]8;;\
#
#  Operation details
#                      Documentation   Create a list of nodes that are cut-points.
#
#                                      Cut-points are any node in a network whose removal disconnects members of the network, creating one
#                                      or more new distinct components.
#
#                                      Uses networkx.articulation_points()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.compon…
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network graph being queried.       yes        -- no default --
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       list           A list of all nodes that are cut-points.
#                                        centrality_network   network_data   Updated network data with eigenvector ranking assigned as a
#                                                                            node attribute.

# %%
centrality_network = output['centrality_network']

output = kiara.run_job('create.cut_point_list', inputs={'network_data':centrality_network})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source   target                                                                                                 │
# │                         ─────────────────                                                                                                │
# │                          14342    32539                                                                                                  │
# │                          14342    32545                                                                                                  │
# │                          14342    14368                                                                                                  │
# │                          14342    4945                                                                                                   │
# │                          14342    11375                                                                                                  │
# │                          8201     15754                                                                                                  │
# │                          22538    4421                                                                                                   │
# │                          12300    11844                                                                                                  │
# │                          12300    32545                                                                                                  │
# │                          34834    32545                                                                                                  │
# │                          18       11844                                                                                                  │
# │                          24595    33158                                                                                                  │
# │                          20501    32545                                                                                                  │
# │                          10266    12118                                                                                                  │
# │                          10266    1683                                                                                                   │
# │                          28700    32545                                                                                                  │
# │                          ...      ...                                                                                                    │
# │                          ...      ...                                                                                                    │
# │                          2108     32703                                                                                                  │
# │                          9876     7460                                                                                                   │
# │                          22166    36167                                                                                                  │
# │                          24220    33765                                                                                                  │
# │                          7460     30709                                                                                                  │
# │                          19426    4084                                                                                                   │
# │                          4084     36656                                                                                                  │
# │                          4084     34411                                                                                                  │
# │                          27141    14328                                                                                                  │
# │                          28688    36753                                                                                                  │
# │                          5139     22082                                                                                                  │
# │                          15915    6531                                                                                                   │
# │                          15528    21163                                                                                                  │
# │                          32462    23534                                                                                                  │
# │                          13018    21258                                                                                                  │
# │                          17762    4087                                                                                                   │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Weighted Degre   Cut Point   Closeness Scor   Degree Score   Betweenness S   label   Eigenvector Sc   id        │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          17               Yes         0.371983114391   5              0.00311885083   14342   0.016931568162   14342     │
# │                          1                No          0.000321027287   1              0.0             8201    5.520694950732   8201      │
# │                          1                No          0.000321027287   1              0.0             22538   5.520694950732   22538     │
# │                          5                No          0.379116008597   2              0.0             12300   0.019316816920   12300     │
# │                          1                No          0.368593865381   1              0.0             34834   0.016153810562   34834     │
# │                          1                No          0.303783345151   1              0.0             18      0.003163006358   18        │
# │                          1                No          0.000321027287   1              0.0             24595   5.520694950732   24595     │
# │                          1                No          0.368593865381   1              0.0             20501   0.016153810562   20501     │
# │                          14               No          0.302038667084   2              0.0             10266   0.003511024481   10266     │
# │                          2                No          0.368852382611   2              0.0             28700   0.016718457282   28700     │
# │                          1                No          0.368593865381   1              0.0             4132    0.016153810562   4132      │
# │                          51               Yes         0.381647116928   8              0.00063722423   28711   0.022853923674   28711     │
# │                          1                No          0.000321027287   1              0.0             8234    5.520694950732   8234      │
# │                          1                No          0.368593865381   1              0.0             8236    0.016153810562   8236      │
# │                          15               No          0.400845828602   6              0.00013032538   14383   0.024972956911   14383     │
# │                          3                Yes         0.368748932216   3              0.00058989021   47      0.016646275823   47        │
# │                          ...              ...         ...              ...            ...             ...     ...              ...       │
# │                          ...              ...         ...              ...            ...             ...     ...              ...       │
# │                          2                No          0.380267337040   2              0.0             11727   0.018556740936   11727     │
# │                          1                No          0.303783345151   1              0.0             3536    0.003163006358   3536      │
# │                          1                No          0.263139060906   1              0.0             16849   0.000383205338   16849     │
# │                          1                No          0.368593865381   1              0.0             19924   0.016153810562   19924     │
# │                          1                No          0.368593865381   1              0.0             36308   0.016153810562   36308     │
# │                          1                No          0.303783345151   1              0.0             33751   0.003163006358   33751     │
# │                          1                No          0.217389933501   1              0.0             18396   3.594740436720   18396     │
# │                          1                No          0.368593865381   1              0.0             35293   0.016153810562   35293     │
# │                          3                No          0.270975745634   2              0.0             1505    0.001050135549   1505      │
# │                          1                No          0.000321027287   1              0.0             23534   5.520694950732   23534     │
# │                          1                No          0.274884866781   1              0.0             5616    0.000648482968   5616      │
# │                          1                No          0.368593865381   1              0.0             24050   0.016153810562   24050     │
# │                          1                No          0.000321027287   1              0.0             4087    5.520694950732   4087      │
# │                          1                No          0.000321027287   1              0.0             14328   5.520694950732   14328     │
# │                          1                No          0.368593865381   1              0.0             36345   0.016153810562   36345     │
# │                          1                No          0.368593865381   1              0.0             32762   0.016153810562   32762     │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Field          Type                 Value                               Description                             │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          item_schema    object               {                                   The schema.                             │
# │                                                                "title": "list",                                                          │
# │                                                                "type": "object"                                                          │
# │                                                              }                                                                           │
# │                                                                                                                                          │
# │                          list_data      array                32545                               The data.                               │
# │                                                              11556                                                                       │
# │                                                              29345                                                                       │
# │                                                              23977                                                                       │
# │                                                              29905                                                                       │
# │                                                              23389                                                                       │
# │                                                              30167                                                                       │
# │                                                              19381                                                                       │
# │                                                              33296                                                                       │
# │                                                              1401                                                                        │
# │                                                              369                                                                         │
# │                                                              23048                                                                       │
# │                                                              25558                                                                       │
# │                                                              29165                                                                       │
# │                                                              15766                                                                       │
# │                                                              35205                                                                       │
# │                                                              14768                                                                       │
# │                                                              12968                                                                       │
# │                                                              25331                                                                       │
# │                                                              35743                                                                       │
# │                                                              28357                                                                       │
# │                                                              17319                                                                       │
# │                                                              1222                                                                        │
# │                                                              21333                                                                       │
# │                                                              37466                                                                       │
# │                                                              33958                                                                       │
# │                                                              15574                                                                       │
# │                                                              25888                                                                       │
# │                                                              15980                                                                       │
# │                                                              3785                                                                        │
# │                                                              12220                                                                       │
# │                                                              34726                                                                       │
# │                                                              32731                                                                       │
# │                                                              29694                                                                       │
# │                                                              35853                                                                       │
# │                                                              170                                                                         │
# │                                                              28286                                                                       │
# │                                                              22947                                                                       │
# │                                                              27174                                                                       │
# │                                                              4106                                                                        │
# │                                                              25663                                                                       │
# │                                                              26092                                                                       │
# │                                                              10043                                                                       │
# │                                                              28420                                                                       │
# │                                                              30098                                                                       │
# │                                                              30633                                                                       │
# │                                                              30624                                                                       │
# │                                                              1595                                                                        │
# │                                                              14412                                                                       │
# │                                                              28252                                                                       │
# │                                                              24509                                                                       │
# │                                                              27012                                                                       │
# │                                                              35246                                                                       │
# │                                                              38185                                                                       │
# │                                                              36153                                                                       │
# │                                                              2863                                                                        │
# │                                                              1572                                                                        │
# │                                                              14590                                                                       │
# │                                                              27060                                                                       │
# │                                                              28867                                                                       │
# │                                                              28124                                                                       │
# │                                                              25317                                                                       │
# │                                                              7449                                                                        │
# │                                                              16061                                                                       │
# │                                                              35474                                                                       │
# │                                                              33719                                                                       │
# │                                                              29606                                                                       │
# │                                                              2579                                                                        │
# │                                                              7572                                                                        │
# │                                                              34995                                                                       │
# │                                                              15560                                                                       │
# │                                                              35382                                                                       │
# │                                                              24163                                                                       │
# │                                                              35258                                                                       │
# │                                                              14368                                                                       │
# │                                                              11375                                                                       │
# │                                                              15837                                                                       │
# │                                                              12287                                                                       │
# │                                                              25933                                                                       │
# │                                                              2585                                                                        │
# │                                                              11844                                                                       │
# │                                                              453                                                                         │
# │                                                              14453                                                                       │
# │                                                              32539                                                                       │
# │                                                              222                                                                         │
# │                                                              1593                                                                        │
# │                                                              14342                                                                       │
# │                                                              35199                                                                       │
# │                                                              181                                                                         │
# │                                                              32798                                                                       │
# │                                                              12219                                                                       │
# │                                                              36071                                                                       │
# │                                                              13562                                                                       │
# │                                                              7460                                                                        │
# │                                                                                                                                          │
# │                          python_class   -- check source --                                       The python class of which model         │
# │                                                                python_class_name    list         instances are created. This is          │
# │                                                                python_module_name   builtins     mostly meant as a hint for client       │
# │                                                                full_name            list         applications.                           │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
output['centrality_network'].lineage
# Out:
# create.cut_point_list
# └── input: network_data (network_data) = 891af0ca-a839-41d6-88ce-d088fc5a6856
#     └── create.closeness_rank_list
#         └── input: network_data (network_data) = f2016302-2e3a-486d-b80d-509407c8e892
#             └── create.eigenvector_rank_list
#                 ├── input: iterations (integer) = 9a4269f0-879b-44d8-af3c-17ece0f96a26
#                 └── input: network_data (network_data) = f2b9b694-1b67-42d7-98f3-5bb6ce2f5d25
#                     └── create.betweenness_rank_list
#                         └── input: network_data (network_data) = 120b3787-dd20-47fc-a3cc-c7ec7c1f81f8
#                             └── create.degree_rank_list
#                                 ├── input: network_data (network_data) = a8c179b5-28f4-4232-a1b7-f61d2630b025
#                                 │   └── create.network_data.from.tables
#                                 │       ├── input: edges (table) = 0b07a000-fdee-4d9c-8cbc-e8d8dd270063
#                                 │       │   └── create.table
#                                 │       │       └── input: file (file) = 7d1efc82-fd63-44ad-a67e-9bc13768f6ba
#                                 │       │           └── download.file
#                                 │       │               ├── input: file_name (string) = 456fa0db-4224-4ddd-a3e0-f08a6f73dc3a
#                                 │       │               └── input: url (string) = 65782aa6-349e-47ba-aecd-76a564e16946
#                                 │       ├── input: edges_column_map (dict) = 3fe6b9cb-315b-47aa-acf0-e890e1a29778
#                                 │       ├── input: id_column_name (string) = 522c1cb7-edf2-406b-91b9-cf3156111c4f
#                                 │       ├── input: label_column_name (string) = d482b36a-aa44-4537-b1fd-ac51d7a61ac7
#                                 │       ├── input: nodes (table) = 57abcf9e-dccb-4ebb-a4ec-9888fd9c0797
#                                 │       ├── input: nodes_column_map (dict) = 7dec48b5-af34-4e62-810e-eacdc41dabed
#                                 │       ├── input: source_column_name (string) = 414ecad3-5013-40ce-b44c-95de35da63d1
#                                 │       └── input: target_column_name (string) = 05063619-21d1-41bb-afda-30da26076962
#                                 ├── input: weight_column_name (string) = 9086e30c-4a4f-4b3d-959d-8b17c005ec36
#                                 └── input: weighted_degree (boolean) = 4bfe1455-e0e1-4ab6-bafe-482d59485b1e

# %%
kiara.retrieve_operation_info('export.network_data.as.graphml_file')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         network_analysis
#                      Labels       package: kiara_plugin.network_analysis
#                      References   source_repo: ]8;id=705196;https://github.com/DHARPA-Project/kiara_plugin.network_analysis\https://github.com/DHARPA-Project/kiara_plugin.network_analysis]8;;\
#                                   documentation: ]8;id=318114;https://DHARPA-Project.github.io/kiara_plugin.network_analysis/\https://DHARPA-Project.github.io/kiara_plugin.network_analysis/]8;;\
#
#  Operation details
#                      Documentation   Export network data as graphml file.
#
#                      Inputs
#                                        field name        type           description                         Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data      network_data   A value of type 'network_data'.     yes        -- no default --
#                                        base_path         string         The directory to export the         no         -- no default --
#                                                                         file(s) to.
#                                        name              string         The (base) name of the exported     no         -- no default --
#                                                                         file(s).
#                                        export_metadata   boolean        Whether to also export the value    no         False
#                                                                         metadata.
#
#
#                      Outputs
#                                        field name       type   description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        export_details   dict   Details about the exported files/folders.
